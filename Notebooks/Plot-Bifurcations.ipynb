# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from tqdm import tqdm

# %%
# %matplotlib notebook

# %%
n = 1200
for col in tqdm(range(n)):
    x = np.load(f'../X_axis/{col}.npy')
    points1 = []
#     points2 = []
    for i in range(1, len(x)-1):
        if x[i-1] < x[i] and x[i] > x[i+1]:
            points1.append(x[i])
            
#         if x[i-1] > x[i] and x[i] < x[i+1]:
#             points2.append(x[i])
    plt.plot([col]*len(points1), points1, 'ro', markersize=0.1)
# Out:
#   0%|          | 0/1200 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="640">
# 100%|██████████| 1200/1200 [01:28<00:00, 13.60it/s]

# %%
for col in tqdm(range(n)):
    x = np.load(f'../X_axis/{col}.npy')
    points2 = []
    for i in range(1, len(x)-1):
        if x[i-1] > x[i] and x[i] < x[i+1]:
            points2.append(x[i])
    plt.plot([col]*len(points2), points2, 'ro', markersize=0.1)
# Out:
#   0%|          | 0/1200 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="640">
# 100%|██████████| 1200/1200 [01:29<00:00, 13.42it/s]
